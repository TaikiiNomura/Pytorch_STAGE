# %%
# !git clone https://github.com/TaikiiNomura/Pytorch_STAGE.git
# %cd Pytorch_STAGE
# !pip install -e .
# Out:
# Cloning into 'Pytorch_STAGE'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 47 (delta 13), reused 42 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 8.22 KiB | 8.22 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/Pytorch_STAGE
# Obtaining file:///content/Pytorch_STAGE
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for stage (pyproject.toml) ... done
#   Created wheel for stage: filename=stage-0.1.0-0.editable-py3-none-any.whl size=3552 sha256=f47f926492d78d651ca9d45b3fa0f72795979bfda6de9a58574f1f662636663d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dezmgdpl/wheels/6d/b0/56/8f2aeaf46a02a5f45149f3f44c167c750b378bba1e8acfb006
# ...

# %%
# %run examples/mnist/mnist_stage-sgd.py --epochs 20 --lr 0.01
# Out:
# Test set: Average loss: 0.2139, Accuracy: 9361/10000 (93.61%)
#
#
# Test set: Average loss: 0.1464, Accuracy: 9558/10000 (95.58%)
#
#
# Test set: Average loss: 0.1103, Accuracy: 9654/10000 (96.54%)
#
#
# Test set: Average loss: 0.0801, Accuracy: 9750/10000 (97.50%)
#
#
# Test set: Average loss: 0.0714, Accuracy: 9787/10000 (97.87%)
#
#
# Test set: Average loss: 0.0591, Accuracy: 9816/10000 (98.16%)
#
#
# Test set: Average loss: 0.0576, Accuracy: 9821/10000 (98.21%)
#
#
# Test set: Average loss: 0.0484, Accuracy: 9841/10000 (98.41%)
#
#
# Test set: Average loss: 0.0457, Accuracy: 9843/10000 (98.43%)
#
#
# Test set: Average loss: 0.0436, Accuracy: 9849/10000 (98.49%)
#
#
# Test set: Average loss: 0.0429, Accuracy: 9855/10000 (98.55%)
#
#
# Test set: Average loss: 0.0396, Accuracy: 9864/10000 (98.64%)
#
#
# Test set: Average loss: 0.0356, Accuracy: 9875/10000 (98.75%)
#
#
# Test set: Average loss: 0.0369, Accuracy: 9878/10000 (98.78%)
#
#
# ...
